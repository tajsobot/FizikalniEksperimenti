# %% [markdown]
# Vaja 10. Prekinjeno nihalo
#
# 1.del - NEPREKINJENO NIHALO

# %%
from cmath import sqrt
from zipimport import alt_path_sep

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

plt.style.use('bmh') #ZELO DOBER PRESET!!!

print(plt.style.available)

df = pd.read_excel("data1.ods", engine="odf")

print(df)
#PAZI!!! PRVA VRSTA SE NE UPOSTEVA !!!!
x = df.iloc[:,0].to_numpy()
y = df.iloc[:,1].to_numpy()
y_cal = df.iloc[:,5].to_numpy()
x_err = df.iloc[:,2].to_numpy()
y_err = df.iloc[:,3].to_numpy()

print(x); print(y); print(x_err); print(y_err)

# Model (linear fit)
def f(x, a, b):
    return a*x + b

# Fit
# params, cov = curve_fit(f, x, y, sigma=y_err)
# a, b = params
# errors = np.sqrt(np.diag(cov))

# Plot

#wow:
plt.errorbar(
    x, y,
    yerr=y_err,
    xerr=x_err,
    fmt='s',  # square markers
    markersize=4,  # smaller dots
    color='#1f3b73',  # dark blue (markers + line)
    ecolor='#444444',  # dark grey error bars
    elinewidth=1,  # thin error lines
    capsize=3,  # "T" caps size
    capthick=1,  # thickness of caps
    markeredgewidth=0.8,
    linestyle='none',  # no connecting lines
    label='meritve'
)
plt.errorbar(
    x, y_cal,
    yerr=0,
    xerr=0,
    fmt='s',  # square markers
    markersize=4,  # smaller dots
    color='#ff0000',  # dark red (markers + line)
    ecolor='#444444',  # dark grey error bars
    elinewidth=1,  # thin error lines
    capsize=3,  # "T" caps size
    capthick=1,  # thickness of caps
    markeredgewidth=0,
    linestyle='none',  # no connecting lines
    label='teorija'
)

x_fit = np.linspace(min(x), max(x), 100)
# plt.plot(x_fit, f(x_fit, a, b), label=f'fit: y={a:.2f}x+{b:.2f}')

plt.legend()
plt.xlabel(r"$\theta\,[^\circ]$")
plt.ylabel(r"$t_0\,[s]$")
plt.show()

# print("a =", a, "±", errors[0])
# print("b =", b, "±", errors[1])

#neke
# Out:
# ['Solarize_Light2', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'petroff6', 'petroff8', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3   Unnamed: 4  Unnamed: 5
# 0           8    1.543333           1        0.01     <podatki    1.549711
# 1          15    1.547667           1        0.01  izracunano>    1.551596
# 2          23    1.554333           1        0.01          NaN    1.556311
# 3          30    1.558333           1        0.01          NaN    1.565110
# 4          38    1.570000           1        0.02          NaN    1.575663
# 5          45    1.607333           1        0.02          NaN    1.590776
# 6          53    1.622667           1        0.02          NaN    1.606448
# 7          60    1.668000           1        0.02          NaN    1.626844
# 8          68    1.694000           1        0.02          NaN    1.646567
# [ 8 15 23 30 38 45 53 60 68]
# [1.54333333 1.54766667 1.55433333 1.55833333 1.57       1.60733333
#  1.62266667 1.668      1.694     ]
# [1 1 1 1 1 1 1 1 1]
# [0.01 0.01 0.01 0.01 0.02 0.02 0.02 0.02 0.02]

# %% [markdown]
# 2.del AMPLITUDA SIMETRIČNO PREKINJENEGA NIHALA

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

plt.style.use('bmh') #ZELO DOBER PRESET!!!

# print(plt.style.available)

df = pd.read_excel("data2.ods", engine="odf")

print(df)

x = df.iloc[:,0].to_numpy()
y = df.iloc[:,1].to_numpy()
y_cal = df.iloc[:,4].to_numpy()
x_cal = x
x_err = df.iloc[:,2].to_numpy()
y_err = df.iloc[:,3].to_numpy()

print(x); print(y); print(x_err); print(y_err)

# Model (linear fit)
def f(x, a, b):
    return a*x + b

# Fit
# params, cov = curve_fit(f, x, y, sigma=y_err)
# a, b = params
# errors = np.sqrt(np.diag(cov))

# Plot

#wow:
plt.errorbar(
    x, y,
    yerr=y_err,
    xerr=x_err,
    fmt='s',  # square markers
    markersize=4,  # smaller dots
    color='#1f3b73',  # dark blue (markers + line)
    ecolor='#444444',  # dark grey error bars
    elinewidth=1,  # thin error lines
    capsize=3,  # "T" caps size
    capthick=1,  # thickness of caps
    markeredgewidth=0.8,
    linestyle='none',  # no connecting lines
    label='meritve'
)
plt.errorbar(
    x_cal, y_cal,
    yerr=0,
    xerr=0,
    fmt='s',  # square markers
    markersize=4,  # smaller dots
    color='#ff0000',  # dark red (markers + line)
    ecolor='#444444',  # dark grey error bars
    elinewidth=1,  # thin error lines
    capsize=3,  # "T" caps size
    capthick=1,  # thickness of caps
    markeredgewidth=0,
    linestyle='none',  # no connecting lines
    label='teorija'
)

x_fit = np.linspace(min(x), max(x), 100)
# plt.plot(x_fit, f(x_fit, a, b), label=f'fit: y={a:.2f}x+{b:.2f}')

plt.legend()
plt.xlabel(r"$\theta_{z}\,[^\circ]$")
plt.ylabel(r"$\theta_{k}\,[^\circ]$")

plt.show()

# print("a =", a, "±", errors[0])
# print("b =", b, "±", errors[1])

#neke
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4   Unnamed: 5
# 0           8          11           2           2   11.322934  <teoreticne
# 1          15          21           2           2   21.274658          NaN
# 2          23          32           2           2   32.753015          NaN
# 3          30          41           2           2   42.941196          NaN
# 4          38          52           2           2   54.828345          NaN
# 5          45          61           2           2   65.529372          NaN
# 6          53          72           2           2   78.249135          NaN
# 7          60          81           2           2   89.997374          NaN
# [ 8 15 23 30 38 45 53 60]
# [11 21 32 41 52 61 72 81]
# [2 2 2 2 2 2 2 2]
# [2 2 2 2 2 2 2 2]

# %% [markdown]
# 3.del - NIHAJNI ČAS SIMETRIČNO PREKINJENEGA NIHALA
#
# 10 nihajev prekinitev 0.3

# %%
#T1 - yl = 0.3

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

plt.style.use('bmh') #ZELO DOBER PRESET!!!

# print(plt.style.available)

df = pd.read_excel("data3.ods", engine="odf")

print(df)
l = 0.597
g = 9.81
prek = 0.179

x = df.iloc[:,1].to_numpy()
y = df.iloc[:,2].to_numpy()
y = y/10
x_cal = x
y_cal = (3.14*((np.sqrt(l/g) + np.sqrt((l-prek)/g)))) * (1 + (((x * 0.01745329)**2/16) * np.sqrt(1/(1-(prek/l)))))

x_err = 0.01
y_err = 0.01

print(x); print(y); print(x_err); print(y_err)

# Model (linear fit)
def f(x, a, b):
    return a*x + b

# Fit
# params, cov = curve_fit(f, x, y, sigma=y_err)
# a, b = params
# errors = np.sqrt(np.diag(cov))

# Plot

#wow:
plt.errorbar(
    x, y,
    yerr=x_err,
    xerr=y_err,
    fmt='s',  # square markers
    markersize=4,  # smaller dots
    color='#1f3b73',  # dark blue (markers + line)
    ecolor='#444444',  # dark grey error bars
    elinewidth=1,  # thin error lines
    capsize=3,  # "T" caps size
    capthick=1,  # thickness of caps
    markeredgewidth=0.8,
    linestyle='none',  # no connecting lines
    label='meritve'
)
plt.errorbar(
    x_cal, y_cal,
    yerr=0,
    xerr=0,
    fmt='s',  # square markers
    markersize=4,  # smaller dots
    color='#ff0000',  # dark red (markers + line)
    ecolor='#444444',  # dark grey error bars
    elinewidth=1,  # thin error lines
    capsize=3,  # "T" caps size
    capthick=1,  # thickness of caps
    markeredgewidth=0,
    linestyle='none',  # no connecting lines
    label='teorija'
)

x_fit = np.linspace(min(x), max(x), 100)
# plt.plot(x_fit, f(x_fit, a, b), label=f'fit: y={a:.2f}x+{b:.2f}')

plt.legend()
plt.xlabel(r"$\theta_{z}\,[^\circ]$")
plt.ylabel(r"$T_0\,[s]$")

plt.show()

# print("a =", a, "±", errors[0])
# print("b =", b, "±", errors[1])

#neke
# Out:
#    N meritev  kot(zavkrozi)  T1(10 nihajev yl =0.3)  T2(10 nihajev yl =0.5)  \
# 0          1            7.5                   14.34                   13.35
# 1          2           15.0                   14.27                   13.34
# 2          3           22.5                   14.53                   13.46
# 3          4           30.0                   14.62                   13.73
# 4          5           37.5                   14.87                   13.82
# 5          6           45.0                   15.00                   14.02
# 6          7           52.5                   15.42                   14.30
# 7          8           60.0                   15.38                   14.52
# 8          9           67.5                   15.47                     NaN
#
#    T3(10 nihajev yl =0.7)  T3(10 nihajev yl =0.9)    asd
# 0                   11.97                    9.99  1.434
# 1                   12.17                   10.07  1.427
# 2                   12.31                   10.34  1.453
# 3                   12.35                     NaN  1.462
# 4                   12.61                     NaN  1.487
# 5                   12.79                     NaN  1.500
# 6                     NaN                     NaN  1.542
# 7                     NaN                     NaN  1.538
# 8                     NaN                     NaN  1.547
# [ 7.5 15.  22.5 30.  37.5 45.  52.5 60.  67.5]
# [1.434 1.427 1.453 1.462 1.487 1.5   1.542 1.538 1.547]
# 0.01
# 0.01

# %% [markdown]
# 10 nihajev prekinitev 0.5

# %%
#T1 - yl = 0.3

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

plt.style.use('bmh') #ZELO DOBER PRESET!!!

# print(plt.style.available)

df = pd.read_excel("data3.ods", engine="odf")

print(df)
l = 0.597
g = 9.81
prek = 0.298

x = df.iloc[:,1].to_numpy()
y = df.iloc[:,3].to_numpy()
y = y/10
x_cal = x
y_cal = (3.14*((np.sqrt(l/g) + np.sqrt((l-prek)/g)))) * (1 + (((x * 0.01745329)**2/16) * np.sqrt(1/(1-(prek/l)))))

x_err = 0.01
y_err = 0.01

print(x); print(y); print(x_err); print(y_err)

# Model (linear fit)
def f(x, a, b):
    return a*x + b

# Fit
# params, cov = curve_fit(f, x, y, sigma=y_err)
# a, b = params
# errors = np.sqrt(np.diag(cov))

# Plot

#wow:
plt.errorbar(
    x, y,
    yerr=x_err,
    xerr=y_err,
    fmt='s',  # square markers
    markersize=4,  # smaller dots
    color='#1f3b73',  # dark blue (markers + line)
    ecolor='#444444',  # dark grey error bars
    elinewidth=1,  # thin error lines
    capsize=3,  # "T" caps size
    capthick=1,  # thickness of caps
    markeredgewidth=0.8,
    linestyle='none',  # no connecting lines
    label='meritve'
)
plt.errorbar(
    x_cal, y_cal,
    yerr=0,
    xerr=0,
    fmt='s',  # square markers
    markersize=4,  # smaller dots
    color='#ff0000',  # dark red (markers + line)
    ecolor='#444444',  # dark grey error bars
    elinewidth=1,  # thin error lines
    capsize=3,  # "T" caps size
    capthick=1,  # thickness of caps
    markeredgewidth=0,
    linestyle='none',  # no connecting lines
    label='teorija'
)

x_fit = np.linspace(min(x), max(x), 100)
# plt.plot(x_fit, f(x_fit, a, b), label=f'fit: y={a:.2f}x+{b:.2f}')

plt.legend()
plt.xlabel(r"$\theta_{z}\,[^\circ]$")
plt.ylabel(r"$T_0\,[s]$")

plt.show()

# print("a =", a, "±", errors[0])
# print("b =", b, "±", errors[1])

#neke
# Out:
#    N meritev  kot(zavkrozi)  T1(10 nihajev yl =0.3)  T2(10 nihajev yl =0.5)  \
# 0          1            7.5                   14.34                   13.35
# 1          2           15.0                   14.27                   13.34
# 2          3           22.5                   14.53                   13.46
# 3          4           30.0                   14.62                   13.73
# 4          5           37.5                   14.87                   13.82
# 5          6           45.0                   15.00                   14.02
# 6          7           52.5                   15.42                   14.30
# 7          8           60.0                   15.38                   14.52
# 8          9           67.5                   15.47                     NaN
#
#    T3(10 nihajev yl =0.7)  T3(10 nihajev yl =0.9)    asd
# 0                   11.97                    9.99  1.434
# 1                   12.17                   10.07  1.427
# 2                   12.31                   10.34  1.453
# 3                   12.35                     NaN  1.462
# 4                   12.61                     NaN  1.487
# 5                   12.79                     NaN  1.500
# 6                     NaN                     NaN  1.542
# 7                     NaN                     NaN  1.538
# 8                     NaN                     NaN  1.547
# [ 7.5 15.  22.5 30.  37.5 45.  52.5 60.  67.5]
# [1.335 1.334 1.346 1.373 1.382 1.402 1.43  1.452   nan]
# 0.01
# 0.01

# %% [markdown]
# 10 nihajev prekinitev 0.7

# %%
#T1 - yl = 0.3

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

plt.style.use('bmh') #ZELO DOBER PRESET!!!

# print(plt.style.available)

df = pd.read_excel("data3.ods", engine="odf")

print(df)
l = 0.597
g = 9.81
prek = 0.418

x = df.iloc[:,1].to_numpy()
y = df.iloc[:,4].to_numpy()
y = y/10
x_cal = x
y_cal = (3.14*((np.sqrt(l/g) + np.sqrt((l-prek)/g)))) * (1 + (((x * 0.01745329)**2/16) * np.sqrt(1/(1-(prek/l)))))

x_err = 0.01
y_err = 0.01

print(x); print(y); print(x_err); print(y_err)

# Model (linear fit)
def f(x, a, b):
    return a*x + b

# Fit
# params, cov = curve_fit(f, x, y, sigma=y_err)
# a, b = params
# errors = np.sqrt(np.diag(cov))

# Plot

#wow:
plt.errorbar(
    x, y,
    yerr=x_err,
    xerr=y_err,
    fmt='s',  # square markers
    markersize=4,  # smaller dots
    color='#1f3b73',  # dark blue (markers + line)
    ecolor='#444444',  # dark grey error bars
    elinewidth=1,  # thin error lines
    capsize=3,  # "T" caps size
    capthick=1,  # thickness of caps
    markeredgewidth=0.8,
    linestyle='none',  # no connecting lines
    label='meritve'
)
plt.errorbar(
    x_cal, y_cal,
    yerr=0,
    xerr=0,
    fmt='s',  # square markers
    markersize=4,  # smaller dots
    color='#ff0000',  # dark red (markers + line)
    ecolor='#444444',  # dark grey error bars
    elinewidth=1,  # thin error lines
    capsize=3,  # "T" caps size
    capthick=1,  # thickness of caps
    markeredgewidth=0,
    linestyle='none',  # no connecting lines
    label='teorija'
)

x_fit = np.linspace(min(x), max(x), 100)
# plt.plot(x_fit, f(x_fit, a, b), label=f'fit: y={a:.2f}x+{b:.2f}')

plt.legend()
plt.xlabel(r"$\theta_{z}\,[^\circ]$")
plt.ylabel(r"$T_0\,[s]$")

plt.show()

# print("a =", a, "±", errors[0])
# print("b =", b, "±", errors[1])

#neke
# Out:
#    N meritev  kot(zavkrozi)  T1(10 nihajev yl =0.3)  T2(10 nihajev yl =0.5)  \
# 0          1            7.5                   14.34                   13.35
# 1          2           15.0                   14.27                   13.34
# 2          3           22.5                   14.53                   13.46
# 3          4           30.0                   14.62                   13.73
# 4          5           37.5                   14.87                   13.82
# 5          6           45.0                   15.00                   14.02
# 6          7           52.5                   15.42                   14.30
# 7          8           60.0                   15.38                   14.52
# 8          9           67.5                   15.47                     NaN
#
#    T3(10 nihajev yl =0.7)  T3(10 nihajev yl =0.9)    asd
# 0                   11.97                    9.99  1.434
# 1                   12.17                   10.07  1.427
# 2                   12.31                   10.34  1.453
# 3                   12.35                     NaN  1.462
# 4                   12.61                     NaN  1.487
# 5                   12.79                     NaN  1.500
# 6                     NaN                     NaN  1.542
# 7                     NaN                     NaN  1.538
# 8                     NaN                     NaN  1.547
# [ 7.5 15.  22.5 30.  37.5 45.  52.5 60.  67.5]
# [1.197 1.217 1.231 1.235 1.261 1.279   nan   nan   nan]
# 0.01
# 0.01

# %% [markdown]
# 10 nihajev prekinitev 0.9

# %%
#T1 - yl = 0.3

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

plt.style.use('bmh') #ZELO DOBER PRESET!!!

# print(plt.style.available)

df = pd.read_excel("data3.ods", engine="odf")

print(df)
l = 0.597
g = 9.81
prek = 0.530

x = df.iloc[:,1].to_numpy()
y = df.iloc[:,5].to_numpy()
y = y/10
x_cal = x
y_cal = (3.14*((np.sqrt(l/g) + np.sqrt((l-prek)/g)))) * (1 + (((x * 0.01745329)**2/16) * np.sqrt(1/(1-(prek/l)))))

x_err = 0.01
y_err = 0.01

print(x); print(y); print(x_err); print(y_err)

# Model (linear fit)
def f(x, a, b):
    return a*x + b

# Fit
# params, cov = curve_fit(f, x, y, sigma=y_err)
# a, b = params
# errors = np.sqrt(np.diag(cov))

# Plot

#wow:
plt.errorbar(
    x, y,
    yerr=x_err,
    xerr=y_err,
    fmt='s',  # square markers
    markersize=4,  # smaller dots
    color='#1f3b73',  # dark blue (markers + line)
    ecolor='#444444',  # dark grey error bars
    elinewidth=1,  # thin error lines
    capsize=3,  # "T" caps size
    capthick=1,  # thickness of caps
    markeredgewidth=0.8,
    linestyle='none',  # no connecting lines
    label='meritve'
)
plt.errorbar(
    x_cal, y_cal,
    yerr=0,
    xerr=0,
    fmt='s',  # square markers
    markersize=4,  # smaller dots
    color='#ff0000',  # dark red (markers + line)
    ecolor='#444444',  # dark grey error bars
    elinewidth=1,  # thin error lines
    capsize=3,  # "T" caps size
    capthick=1,  # thickness of caps
    markeredgewidth=0,
    linestyle='none',  # no connecting lines
    label='teorija'
)

x_fit = np.linspace(min(x), max(x), 100)
# plt.plot(x_fit, f(x_fit, a, b), label=f'fit: y={a:.2f}x+{b:.2f}')

plt.legend()
plt.xlabel(r"$\theta_{z}\,[^\circ]$")
plt.ylabel(r"$T_0\,[s]$")

plt.show()

# print("a =", a, "±", errors[0])
# print("b =", b, "±", errors[1])

#neke
# Out:
#    N meritev  kot(zavkrozi)  T1(10 nihajev yl =0.3)  T2(10 nihajev yl =0.5)  \
# 0          1            7.5                   14.34                   13.35
# 1          2           15.0                   14.27                   13.34
# 2          3           22.5                   14.53                   13.46
# 3          4           30.0                   14.62                   13.73
# 4          5           37.5                   14.87                   13.82
# 5          6           45.0                   15.00                   14.02
# 6          7           52.5                   15.42                   14.30
# 7          8           60.0                   15.38                   14.52
# 8          9           67.5                   15.47                     NaN
#
#    T3(10 nihajev yl =0.7)  T3(10 nihajev yl =0.9)    asd
# 0                   11.97                    9.99  1.434
# 1                   12.17                   10.07  1.427
# 2                   12.31                   10.34  1.453
# 3                   12.35                     NaN  1.462
# 4                   12.61                     NaN  1.487
# 5                   12.79                     NaN  1.500
# 6                     NaN                     NaN  1.542
# 7                     NaN                     NaN  1.538
# 8                     NaN                     NaN  1.547
# [ 7.5 15.  22.5 30.  37.5 45.  52.5 60.  67.5]
# [0.999 1.007 1.034   nan   nan   nan   nan   nan   nan]
# 0.01
# 0.01

# %% [markdown]
# Nihalo se je pri $\theta = 69^\circ$ zavrtelo okoli osi. Preko enačbe za možen zasuk $\theta_z = 66.4^\circ$ pri $y/l = 0.7$, da je $\theta_k = 180^\circ$.

# %% [markdown]
# 4. del: ASIMETRIČNO PREKINJENO NIHALO

# %%
import math

l = 0.597
y = 0.298
g = 9.81
theta_0 = 45 * 0.01745329
theta_02 = 71 * 0.01745329
alpha = 30 * 0.01745329

t1 = 2 * math.pi * math.sqrt(l / g)
t2 = 2 * math.pi * math.sqrt((l - y) / g)

t = math.pi * (math.sqrt(l / g) + math.sqrt((l - y) / g))
print(f"l={l}, y={y}, theta_0={theta_0}, theta_02={theta_02}, alpha={alpha}")
t0 = t * (1 + (1 / (math.pi * t)) * (t1 * math.asin(alpha / theta_0) - t2 * math.asin(alpha / theta_02))) * (1 + theta_02**2 / 16 * 1 / (1 - y / l))

print(t0)
# Out:
# l=0.597, y=0.298, theta_0=0.78539805, theta_02=1.23918359, alpha=0.5235987
# 1.8245973925244952

# %% [markdown]
# Izmerjene vrednosti:
# $t_{45^\circ} = 1.6 \pm 0.1$
