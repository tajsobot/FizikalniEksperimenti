# %% [markdown]
# 2. UKLON IN INTERFERENCA

# %% [markdown]
# 1.1 del:
#
# Določiti valovno dolžino svetlobe iz laserja:
#
# $$
# \begin{array}{}
#     N = 3 \\
#     a = \frac{1}{450} mm  = 2.22\mu m \\
# \end{array}
# $$
#
# Izračunani koti pri 3. ojačitvi:
# $$
# \begin{array}{|c|c|}
# \hline
# \beta [^\circ]\\
# \hline
# 57.7 \pm 0.3 \\
# 57.5 \pm 0.3 \\
# 57.4 \pm 0.3 \\
# \hline
# \end{array}
# $$
#
# $$ \bar{\beta} = 57.6 \pm 0.3 $$
#
# $$ \lambda =  \frac{a * sin(\beta)}{N} = 625 (1 \pm 0.02)nm = (630 \pm 10)nm$$

# %% [markdown]
# 1.2 del:
#
# Uklon preko
#
# Reže:
#
# $$
# s_{10} = (41.1 \pm 0.1) mm
# $$
#
# $$
# l = (1154 \pm 0.3) mm
# $$
#
# $$
# x = \frac{41.1}{9} = (4.57 \pm 0.02) mm
# $$
#
# $$
# b = \frac{\lambda l }{x} = 1.59 (1 \pm 0.03)\mu m = (1.59 \pm 0.05) \mu m
# $$

# %% [markdown]
# Žičke:
#
# $$
# s_{12} = (106.2 \pm 0.1) mm
# $$
#
# $$
# l = (1125 \pm 0.3) mm
# $$
#
# $$
# x = \frac{106.2}{11} = (9.65 \pm 0.02) mm
# $$
#
# $$
# b = \frac{\lambda l }{x} = 73.7 (1 \pm 0.04)\mu m = (73.7 \pm 0.3) \mu m
# $$
#
# Z mikrometrom:
#
# $$
# b = (70 \pm 10) \mu m
# $$

# %% [markdown]
# Sito:
#
# $$
# s_{12} = (106.2 \pm 0.1) mm
# $$
#
# $$
# l = (1125 \pm 0.3) mm
# $$
#
# $$
# x = \frac{106.2}{11} = (9.65 \pm 0.02) mm
# $$
#
# $$
# b = \frac{\lambda l }{x} = 73.7 (1 \pm 0.04)\mu m = (73.7 \pm 0.3) \mu m
# $$
#
# Dobili smo zanimivo oklonsko sliko. Ojačitve so bile grupirane znotraj večjih segmentov ojačitve. Večje zaradi samih lukenj male zaradi same debeline vlaken v situ.

# %% [markdown]
# 2. del :
#
# Meritve:
#
# $$
# l = 148.3 \pm 0.1 cm
# $$
# $$
# \begin{array}{|c|c|}
# \hline
# N & d [cm]\\
# \hline
# 1 & 28.1 \pm 0.1 \\
# 2 & 57.8 \pm 0.1 \\
# 3 & 93.9 \pm 0.1 \\
# \hline
# \end{array}
# $$
#
# $$
# l = 113.4 \pm 0.1 cm
# $$
# $$
# \begin{array}{|c|c|}
# \hline
# N & d [cm]\\
# \hline
# 1 & 28.1 \pm 0.1 \\
# 2 & 57.8 \pm 0.1 \\
# 3 & 93.9 \pm 0.1 \\
# 4 & 93.9 \pm 0.1 \\
# \hline
# \end{array}
# $$
#
# $$
# l = 148.3 \pm 0.1 cm
# $$
# $$
# \begin{array}{|c|c|}
# \hline
# N & d [cm]\\
# \hline
# 1 & 28.1 \pm 0.1 \\
# 2 & 57.8 \pm 0.1 \\
# 3 & 93.9 \pm 0.1 \\
# \hline
# \end{array}
# $$
