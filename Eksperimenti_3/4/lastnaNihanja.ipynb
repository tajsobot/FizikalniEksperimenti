# %% [markdown]
# Lastno nihanje 1:
# $$
# \begin{array}{|c|c|}
# \hline
# n & t [s] \\
# \hline
# 10 & 15.3 \pm 0.2s\\
# 20 & 34.0   \pm 0.2s\\
# 32 & 51.9 \pm 0.2s\\
# \hline
# \end{array}
# $$
#
# $$
# T_{pln} = (1.62 \pm 0.01)s = 1.62 (1 \pm 0.006)
# $$
# Rezultat je enak kot pri posameznem nihalu $\checkmark$

# %% [markdown]
# Lastno nihanje 2:
#
# $$
# \begin{array}{|c|c|}
# \hline
# n & t [s] \\
# \hline
# 26 & 34.5  \pm 0.5s\\
# 30 & 38.4 \pm 0.5s\\
# 40 & 51.2 \pm 0.5s\\
# \hline
# \end{array}
# $$
# $$
# T_{dln} = (1.275 \pm 0.01)s = 1.275 (1 \pm 0.004)
# $$
#
# Teoretična napoved:
#
# $$
# T = 2\pi \sqrt{\frac{J}{m g d + 2 k b^2}}
# $$

# %%
from typing import Protocol

import math as m
J = 0.588 #nm2
m = 1.292 #kg
d = 0.656 #m
k = 7.5 #nm
b = 0.645 #m
g = 9.8 #ms-2

print(2*3.14159*(J/(m*g*d+2*k*b*b))**(1/2))
# Out:
# 1.2632538531619775

# %% [markdown]
# Utripanje:
#
# Meritve za število utripov $n$ v času $t$.
# $$
# \begin{array}{|c|c|}
# \hline
# n & t [s] \\
# \hline
# 5 & 27.1  \pm 0.5s\\
# 10 & 54.4 \pm 0.5s\\
# 11 & 59.7 \pm 0.5s\\
# \hline
# \end{array}
# $$
#
# Izračunamo čas enega utripa: $T_{utr} = (5.43 \pm 0.02)s$

# %%
T1 = 1.62
T2 = 1.275
print(1/(1/T2 - 1/T1))
# Out:
# 5.986956521739126
