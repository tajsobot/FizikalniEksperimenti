# %% [markdown]
# Vaja 4: Sklopljeno nihanje dveh enakih fizikalnih nihal.

# %% [markdown]
# Prvo smo izmerili lastne frekvence vsakega nihala.
# Tabela meritev, število nihajev $n$ in čas $t$, dvakrat po po ~30 nihajev.
#
# $$
# \begin{array}{|c|c|}
# \hline
# n & t [s] \\
# \hline
# 10 & 15.2 \pm 0.2s\\
# 20 & 34.0   \pm 0.2s\\
# 32 & 51.9 \pm 0.2s\\
# \hline
# \end{array}
# $$
# $$T_{lastna1} = (1.62 \pm 0.01) s$$
# $$
# \begin{array}{|c|c|}
# \hline
# n & t [s] \\
# \hline
# 10 & 16.5 \pm 0.2s\\
# 23 & 38.0 \pm 0.2s\\
# 32 & 50.0 \pm 0.2s\\
# \hline
# \end{array}
# $$
# $$T_{lastna2} = (1.56 \pm 0.01) s$$

# %% [markdown]
# Teoretični izračun lastnih frekvenc:
#
# $$
# T_{izracunana} = (1.7 \pm 0.1)s
# $$
# Rezultat se ujema z teorijo$\checkmark$
# ![izpeljava.jpg](izpeljava.jpg)
